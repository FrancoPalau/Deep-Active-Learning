# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Experiment random pos for LSTM with different maxlen

# %%
sizes_string = [10, 25, 75]

for maxlen in sizes_string:
    train = "./Random_pos/ctu13subs" + str(maxlen) + "_net.csv"
    test = "ctu19_for_LSTM_random_pos_size_" + str(maxlen) + ".csv"
    results = "results_LSTM_random_pos_size_" + str(maxlen) + ".csv"
    for i in range(0,10):
        # !python3 train_data_preparation.py --csv $train --maxlen $maxlen
        # !python3 dga_classifier.py --save-model endgame.h5 --maxlen $maxlen
        # !python3 train_data_preparation.py --csv $test --test-only --maxlen $maxlen
        # !python3 dga_classifier.py --test-only -m endgame.h5 -r $results --maxlen $maxlen
        print("##--------------------------------------------------------------------##")
# Out:
# Using TensorFlow backend.
# Using TensorFlow backend.
# (7251, 10) (7251,)
# (18, 10) (18,)
# Model lstm_model_endgame selected
# Training model...
# (7251,)
# Train on 7251 samples, validate on 18 samples
# Epoch 1/30
# 2020-04-19 17:12:24.288283: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-04-19 17:12:24.558308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-19 17:12:24.558802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1344] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:01:00.0
# totalMemory: 10.92GiB freeMemory: 10.77GiB
# 2020-04-19 17:12:24.558817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1423] Adding visible gpu devices: 0
# ...

# %% [markdown]
# ### Experiment LSTM different maxlen from beginning

# %%
sizes_string = [10, 25]#, 75, 100, 500, 1000]
test = "ctu19_to_test.csv"
train = "ctu_13_for_LSTM.csv"
for maxlen in sizes_string:
    results = "results_LSTM_size_" + str(maxlen) + ".csv"
    for i in range(0,10):
        # !python3 train_data_preparation.py --csv $train --maxlen $maxlen
        # !python3 dga_classifier.py --save-model endgame.h5 --maxlen $maxlen
        # !python3 train_data_preparation.py --csv $test --test-only --maxlen $maxlen
        # !python3 dga_classifier.py --test-only -m endgame.h5 -r $results --maxlen $maxlen
        print("##--------------------------------------------------------------------##")
# Out:
# Using TensorFlow backend.
#   File "dga_classifier.py", line 54
#     print(test_x_data.shape, test_y_data.shape)
#                                               ^
# TabError: inconsistent use of tabs and spaces in indentation
# Using TensorFlow backend.
#   File "dga_classifier.py", line 54
#     print(test_x_data.shape, test_y_data.shape)
#                                               ^
# TabError: inconsistent use of tabs and spaces in indentation
# ##--------------------------------------------------------------------##
# Using TensorFlow backend.
#   File "dga_classifier.py", line 54
#     print(test_x_data.shape, test_y_data.shape)
#                                               ^
# TabError: inconsistent use of tabs and spaces in indentation
# Using TensorFlow backend.
#   File "dga_classifier.py", line 54
#     print(test_x_data.shape, test_y_data.shape)
#                                               ^
# TabError: inconsistent use of tabs and spaces in indentation
# ...
