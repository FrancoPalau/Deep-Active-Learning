# %% [markdown]
# ## CTU RESULTS FROM EXPERIMENTS

# %% [markdown]
# Resultados CNN tunnel( 256 filtros + densa 256, batch=256,epochs=10) cortando en 1000 las cadenas
#
# ```
# [[ 785   44]
#  [ 112 1752]]
#               precision    recall  f1-score   support
#
#       normal     0.8751    0.9469    0.9096       829
#       botnet     0.9755    0.9399    0.9574      1864
#
#    micro avg     0.9421    0.9421    0.9421      2693
#    macro avg     0.9253    0.9434    0.9335      2693
# weighted avg     0.9446    0.9421    0.9427      2693
#
# TN:  785
# FP:  44
# FN:  112
# TP:  1752
# False Alarm Rate:  0.05307599517490953
# Precision Rate:  0.9755011135857461
# Recall Rate:  0.9399141630901288
# ```

# %% [markdown]
# Resultados LSTM woodbridge (batch=256, epochs=1) cortando en 1000 las cadenas
# ```
# [[   5  824]
#  [   0 1864]]
#               precision    recall  f1-score   support
#
#       normal     1.0000    0.0060    0.0120       829
#       botnet     0.6935    1.0000    0.8190      1864
#
#    micro avg     0.6940    0.6940    0.6940      2693
#    macro avg     0.8467    0.5030    0.4155      2693
# weighted avg     0.7878    0.6940    0.5706      2693
#
# TN:  5
# FP:  824
# FN:  0
# TP:  1864
# False Alarm Rate:  0.9939686369119421
# Precision Rate:  0.6934523809523809
# Recall Rate:  1.0
# ```

# %% [markdown]
# Resultados LSTM woodbridge + densa 256 (batch=256, epochs=1) cortando en 1000 las cadenas
#
# ```
# [[   0  829]
#  [   0 1864]]
#
#               precision    recall  f1-score   support
#
#       normal     0.0000    0.0000    0.0000       829
#       botnet     0.6922    1.0000    0.8181      1864
#
#    micro avg     0.6922    0.6922    0.6922      2693
#    macro avg     0.3461    0.5000    0.4090      2693
# weighted avg     0.4791    0.6922    0.5662      2693
#
# TN:  0
# FP:  829
# FN:  0
# TP:  1864
# False Alarm Rate:  1.0
# Precision Rate:  0.6921648718900854
# Recall Rate:  1.0
# ```

# %% [markdown]
# Resultados LSTM woodbridge (batch=256, epochs=10) cortando en 75 las cadenas
# ```
# [[ 811   18]
#  [ 371 1493]]
#               precision    recall  f1-score   support
#
#       normal     0.6861    0.9783    0.8066       829
#       botnet     0.9881    0.8010    0.8847      1864
#
#    micro avg     0.8556    0.8556    0.8556      2693
#    macro avg     0.8371    0.8896    0.8457      2693
# weighted avg     0.8951    0.8556    0.8607      2693
#
# TN:  811
# FP:  18
# FN:  371
# TP:  1493
# False Alarm Rate:  0.021712907117008445
# Precision Rate:  0.9880873593646592
# Recall Rate:  0.8009656652360515
# ```

# %% [markdown]
# Resultados LSTM woodbridge (batch=256, epochs=20) cortando en 75 las cadenas
# ```
# [[ 671  158]
#  [  91 1773]]
#               precision    recall  f1-score   support
#
#       normal     0.8806    0.8094    0.8435       829
#       botnet     0.9182    0.9512    0.9344      1864
#
#    micro avg     0.9075    0.9075    0.9075      2693
#    macro avg     0.8994    0.8803    0.8889      2693
# weighted avg     0.9066    0.9075    0.9064      2693
#
# TN:  671
# FP:  158
# FN:  91
# TP:  1773
# False Alarm Rate:  0.19059107358262967
# Precision Rate:  0.9181771103055412
# Recall Rate:  0.9511802575107297
#
# ```

# %% [markdown]
# Resultados LSTM woodbridge + densa 512 (batch=256, epochs=30) cortando en 75 las cadenas
# ```
# [[ 771   58]
#  [ 147 1717]]
#               precision    recall  f1-score   support
#
#       normal     0.8399    0.9300    0.8827       829
#       botnet     0.9673    0.9211    0.9437      1864
#
#    micro avg     0.9239    0.9239    0.9239      2693
#    macro avg     0.9036    0.9256    0.9132      2693
# weighted avg     0.9281    0.9239    0.9249      2693
#
# TN:  771
# FP:  58
# FN:  147
# TP:  1717
# False Alarm Rate:  0.06996381182147166
# Precision Rate:  0.9673239436619718
# Recall Rate:  0.921137339055794
#
# ```

# %% [markdown]
# Misma estructura que anterior pero cortando en 1000 las cadenas
# ```
# [[  19  810]
#  [   0 1864]]
#               precision    recall  f1-score   support
#
#       normal     1.0000    0.0229    0.0448       829
#       botnet     0.6971    1.0000    0.8215      1864
#
#    micro avg     0.6992    0.6992    0.6992      2693
#    macro avg     0.8485    0.5115    0.4332      2693
# weighted avg     0.7903    0.6992    0.5824      2693
#
# TN:  19
# FP:  810
# FN:  0
# TP:  1864
# False Alarm Rate:  0.97708082026538
# Precision Rate:  0.6970830216903515
# Recall Rate:  1.0
# ```

# %% [markdown]
# Misma estructura que anterior, cortando a los 1000 pero con Masking
# ```
# [[ 745   84]
#  [  86 1778]]
#               precision    recall  f1-score   support
#
#       normal     0.8965    0.8987    0.8976       829
#       botnet     0.9549    0.9539    0.9544      1864
#
#    micro avg     0.9369    0.9369    0.9369      2693
#    macro avg     0.9257    0.9263    0.9260      2693
# weighted avg     0.9369    0.9369    0.9369      2693
#
# TN:  745
# FP:  84
# FN:  86
# TP:  1778
# False Alarm Rate:  0.10132689987937274
# Precision Rate:  0.9548872180451128
# Recall Rate:  0.953862660944206
#
# ```

# %% [markdown]
# ### RANDOM FOREST

# %% [markdown]
# Random Forest, feature vector, cadenas completas
# ```
# [[ 713   99]
#  [ 109 1799]]
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87       812
#            1       0.95      0.94      0.95      1908
#
#     accuracy                           0.92      2720
#    macro avg       0.91      0.91      0.91      2720
# weighted avg       0.92      0.92      0.92      2720
#
# ```

# %% [markdown]
# Random Forest, feature vector, cadenas sin los primeros 5 caracteres
# ```
# [[ 609  121]
#  [  85 1201]]
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86       730
#            1       0.91      0.93      0.92      1286
#
#     accuracy                           0.90      2016
#    macro avg       0.89      0.88      0.89      2016
# weighted avg       0.90      0.90      0.90      2016
#
#
# ```

# %% [markdown]
# Random Forest, feature vector, cadenas sin los primeros 5 caracteres, maxlen=75
# ```
# [[ 580  118]
#  [  87 1231]]
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       698
#            1       0.91      0.93      0.92      1318
#
#     accuracy                           0.90      2016
#    macro avg       0.89      0.88      0.89      2016
# weighted avg       0.90      0.90      0.90      2016
#
# ```

# %% [markdown]
# Random Forest, feature vector, cadenas sin los primeros 5 caracteres, maxlen=100
# ```
# [[ 620  125]
#  [  87 1184]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85       745
#            1       0.90      0.93      0.92      1271
#
#     accuracy                           0.89      2016
#    macro avg       0.89      0.88      0.89      2016
# weighted avg       0.89      0.89      0.89      2016
# ```

# %% [markdown]
# Random Forest, feature vector, cadenas sin los primeros 5 caracteres, maxlen=200
# ```
# [[ 578  110]
#  [  82 1246]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86       688
#            1       0.92      0.94      0.93      1328
#
#     accuracy                           0.90      2016
#    macro avg       0.90      0.89      0.89      2016
# weighted avg       0.90      0.90      0.90      2016
# ```

# %% [markdown]
# Random Forest, feature vector, cadenas sin los primeros 5 caracteres, maxlen=500
# ```
# [[ 591  124]
#  [  83 1218]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85       715
#            1       0.91      0.94      0.92      1301
#
#     accuracy                           0.90      2016
#    macro avg       0.89      0.88      0.89      2016
# weighted avg       0.90      0.90      0.90      2016
# ```

# %% [markdown]
# Random Forest, feature vector, cadenas sin los primeros 5 caracteres, maxlen=1000
# ```
# [[ 611  106]
#  [ 105 1194]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       717
#            1       0.92      0.92      0.92      1299
#
#     accuracy                           0.90      2016
#    macro avg       0.89      0.89      0.89      2016
# weighted avg       0.90      0.90      0.90      2016
# ```

# %% [markdown]
# ### LSTM

# %% [markdown]
# LSTM sin los primeros 5 caracteres y con maxlen=75
# ```
# [[ 602   98]
#  [  81 1215]]
#               precision    recall  f1-score   support
#
#       normal     0.8814    0.8600    0.8706       700
#       botnet     0.9254    0.9375    0.9314      1296
#
#    micro avg     0.9103    0.9103    0.9103      1996
#    macro avg     0.9034    0.8987    0.9010      1996
# weighted avg     0.9099    0.9103    0.9101      1996
#
# TN:  602
# FP:  98
# FN:  81
# TP:  1215
# False Alarm Rate:  0.14
# Precision Rate:  0.9253617669459253
# Recall Rate:  0.9375
# ```

# %% [markdown]
# LSTM sin los primeros 5 caracteres y con maxlen=100
# ```
# [[ 625   75]
#  [  97 1199]]
#               precision    recall  f1-score   support
#
#       normal     0.8657    0.8929    0.8790       700
#       botnet     0.9411    0.9252    0.9331      1296
#
#    micro avg     0.9138    0.9138    0.9138      1996
#    macro avg     0.9034    0.9090    0.9061      1996
# weighted avg     0.9147    0.9138    0.9141      1996
#
# TN:  625
# FP:  75
# FN:  97
# TP:  1199
# False Alarm Rate:  0.10714285714285714
# Precision Rate:  0.9411302982731554
# Recall Rate:  0.9251543209876543
# ```

# %% [markdown]
# LSTM sin los primeros 5 caracteres y con maxlen=200
# ```
# [[ 607   93]
#  [  71 1225]]
#               precision    recall  f1-score   support
#
#       normal     0.8953    0.8671    0.8810       700
#       botnet     0.9294    0.9452    0.9373      1296
#
#    micro avg     0.9178    0.9178    0.9178      1996
#    macro avg     0.9124    0.9062    0.9091      1996
# weighted avg     0.9175    0.9178    0.9175      1996
#
# TN:  607
# FP:  93
# FN:  71
# TP:  1225
# False Alarm Rate:  0.13285714285714287
# Precision Rate:  0.9294385432473444
# Recall Rate:  0.9452160493827161
# ```

# %% [markdown]
# LSTM sin los primeros 5 caracteres y con maxlen=500
# ```
# [[ 635   65]
#  [  79 1217]]
#               precision    recall  f1-score   support
#
#       normal     0.8894    0.9071    0.8982       700
#       botnet     0.9493    0.9390    0.9441      1296
#
#    micro avg     0.9279    0.9279    0.9279      1996
#    macro avg     0.9193    0.9231    0.9212      1996
# weighted avg     0.9283    0.9279    0.9280      1996
#
# TN:  635
# FP:  65
# FN:  79
# TP:  1217
# False Alarm Rate:  0.09285714285714286
# Precision Rate:  0.9492979719188768
# Recall Rate:  0.9390432098765432
# ```

# %% [markdown]
# LSTM sin los primeros 5 caracteres y con maxlen=1000
# ```
# [[ 633   67]
#  [  87 1209]]
#               precision    recall  f1-score   support
#
#       normal     0.8792    0.9043    0.8915       700
#       botnet     0.9475    0.9329    0.9401      1296
#
#    micro avg     0.9228    0.9228    0.9228      1996
#    macro avg     0.9133    0.9186    0.9158      1996
# weighted avg     0.9235    0.9228    0.9231      1996
#
# TN:  633
# FP:  67
# FN:  87
# TP:  1209
# False Alarm Rate:  0.09571428571428571
# Precision Rate:  0.9474921630094044
# Recall Rate:  0.9328703703703703
# ```

# %% [markdown]
# ### RANDOM POSITION EXPERIMENT
# maxlen = 25

# %% [markdown]
# random forest
# ```
# [[ 590  124]
#  [ 103 1199]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       714
#            1       0.91      0.92      0.91      1302
#
#     accuracy                           0.89      2016
#    macro avg       0.88      0.87      0.88      2016
# weighted avg       0.89      0.89      0.89      2016
# ```

# %% [markdown]
# LSTM
# ```
# [[554 146]
#  [300 996]]
#               precision    recall  f1-score   support
#
#       normal     0.6487    0.7914    0.7130       700
#       botnet     0.8722    0.7685    0.8171      1296
#
#    micro avg     0.7766    0.7766    0.7766      1996
#    macro avg     0.7604    0.7800    0.7650      1996
# weighted avg     0.7938    0.7766    0.7806      1996
#
# TN:  554
# FP:  146
# FN:  300
# TP:  996
# False Alarm Rate:  0.20857142857142857
# Precision Rate:  0.87215411558669
# Recall Rate:  0.7685185185185185
# ```

# %% [markdown]
# RANDOM POSITION 10 EXPERIMENTS MAXLEN=25 RF
# ```
# [[ 561  248]
#  [ 111 1800]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.69      0.76       809
#            1       0.88      0.94      0.91      1911
#
#     accuracy                           0.87      2720
#    macro avg       0.86      0.82      0.83      2720
# weighted avg       0.87      0.87      0.86      2720
#
# [[ 596  235]
#  [ 122 1767]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77       831
#            1       0.88      0.94      0.91      1889
#
#     accuracy                           0.87      2720
#    macro avg       0.86      0.83      0.84      2720
# weighted avg       0.87      0.87      0.87      2720
#
# [[ 561  252]
#  [ 121 1786]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75       813
#            1       0.88      0.94      0.91      1907
#
#     accuracy                           0.86      2720
#    macro avg       0.85      0.81      0.83      2720
# weighted avg       0.86      0.86      0.86      2720
#
# [[ 572  243]
#  [ 117 1788]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.70      0.76       815
#            1       0.88      0.94      0.91      1905
#
#     accuracy                           0.87      2720
#    macro avg       0.86      0.82      0.83      2720
# weighted avg       0.87      0.87      0.86      2720
#
# [[ 575  267]
#  [ 109 1769]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.68      0.75       842
#            1       0.87      0.94      0.90      1878
#
#     accuracy                           0.86      2720
#    macro avg       0.85      0.81      0.83      2720
# weighted avg       0.86      0.86      0.86      2720
#
# [[ 592  243]
#  [ 125 1760]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.76       835
#            1       0.88      0.93      0.91      1885
#
#     accuracy                           0.86      2720
#    macro avg       0.85      0.82      0.83      2720
# weighted avg       0.86      0.86      0.86      2720
#
# [[ 567  213]
#  [ 127 1813]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.73      0.77       780
#            1       0.89      0.93      0.91      1940
#
#     accuracy                           0.88      2720
#    macro avg       0.86      0.83      0.84      2720
# weighted avg       0.87      0.88      0.87      2720
#
# [[ 615  243]
#  [  93 1769]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.72      0.79       858
#            1       0.88      0.95      0.91      1862
#
#     accuracy                           0.88      2720
#    macro avg       0.87      0.83      0.85      2720
# weighted avg       0.88      0.88      0.87      2720
#
# [[ 583  235]
#  [ 132 1770]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.71      0.76       818
#            1       0.88      0.93      0.91      1902
#
#     accuracy                           0.87      2720
#    macro avg       0.85      0.82      0.83      2720
# weighted avg       0.86      0.87      0.86      2720
#
# [[ 561  270]
#  [ 101 1788]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.75       831
#            1       0.87      0.95      0.91      1889
#
#     accuracy                           0.86      2720
#    macro avg       0.86      0.81      0.83      2720
# weighted avg       0.86      0.86      0.86      2720
#
# ```

# %% [markdown]
# RANDOM POSITION 10 EXPERIMENTS MAXLEN=75 RF
# ```
# [[ 606  244]
#  [  99 1771]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.71      0.78       850
#            1       0.88      0.95      0.91      1870
#
#     accuracy                           0.87      2720
#    macro avg       0.87      0.83      0.85      2720
# weighted avg       0.87      0.87      0.87      2720
#
# [[ 604  222]
#  [  94 1800]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79       826
#            1       0.89      0.95      0.92      1894
#
#     accuracy                           0.88      2720
#    macro avg       0.88      0.84      0.86      2720
# weighted avg       0.88      0.88      0.88      2720
#
# [[ 598  232]
#  [ 120 1770]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77       830
#            1       0.88      0.94      0.91      1890
#
#     accuracy                           0.87      2720
#    macro avg       0.86      0.83      0.84      2720
# weighted avg       0.87      0.87      0.87      2720
#
# [[ 620  227]
#  [  93 1780]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79       847
#            1       0.89      0.95      0.92      1873
#
#     accuracy                           0.88      2720
#    macro avg       0.88      0.84      0.86      2720
# weighted avg       0.88      0.88      0.88      2720
#
# [[ 585  244]
#  [  94 1797]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.71      0.78       829
#            1       0.88      0.95      0.91      1891
#
#     accuracy                           0.88      2720
#    macro avg       0.87      0.83      0.84      2720
# weighted avg       0.87      0.88      0.87      2720
#
# [[ 603  237]
#  [ 115 1765]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.72      0.77       840
#            1       0.88      0.94      0.91      1880
#
#     accuracy                           0.87      2720
#    macro avg       0.86      0.83      0.84      2720
# weighted avg       0.87      0.87      0.87      2720
#
# [[ 598  249]
#  [  93 1780]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.71      0.78       847
#            1       0.88      0.95      0.91      1873
#
#     accuracy                           0.87      2720
#    macro avg       0.87      0.83      0.84      2720
# weighted avg       0.87      0.87      0.87      2720
#
# [[ 596  255]
#  [  96 1773]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.70      0.77       851
#            1       0.87      0.95      0.91      1869
#
#     accuracy                           0.87      2720
#    macro avg       0.87      0.82      0.84      2720
# weighted avg       0.87      0.87      0.87      2720
#
# [[ 592  244]
#  [ 104 1780]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77       836
#            1       0.88      0.94      0.91      1884
#
#     accuracy                           0.87      2720
#    macro avg       0.87      0.83      0.84      2720
# weighted avg       0.87      0.87      0.87      2720
#
# [[ 578  256]
#  [  98 1788]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.69      0.77       834
#            1       0.87      0.95      0.91      1886
#
#     accuracy                           0.87      2720
#    macro avg       0.86      0.82      0.84      2720
# weighted avg       0.87      0.87      0.87      2720
#
# ```

# %% [markdown]
# RANDOM POSITION 10 EXPERIMENTS MAXLEN=25 lSTM
# ```
# [[ 574  126]
#  [ 293 1003]]
#               precision    recall  f1-score   support
#
#       normal     0.6621    0.8200    0.7326       700
#       botnet     0.8884    0.7739    0.8272      1296
#
#    micro avg     0.7901    0.7901    0.7901      1996
#    macro avg     0.7752    0.7970    0.7799      1996
# weighted avg     0.8090    0.7901    0.7940      1996
#
# TN:  574
# FP:  126
# FN:  293
# TP:  1003
# False Alarm Rate:  0.18
# Precision Rate:  0.8883968113374667
# Recall Rate:  0.7739197530864198
#
# [[ 465  235]
#  [ 189 1107]]
#               precision    recall  f1-score   support
#
#       normal     0.7110    0.6643    0.6869       700
#       botnet     0.8249    0.8542    0.8393      1296
#
#    micro avg     0.7876    0.7876    0.7876      1996
#    macro avg     0.7679    0.7592    0.7631      1996
# weighted avg     0.7850    0.7876    0.7858      1996
#
# TN:  465
# FP:  235
# FN:  189
# TP:  1107
# False Alarm Rate:  0.3357142857142857
# Precision Rate:  0.8248882265275708
# Recall Rate:  0.8541666666666666
#
# [[ 447  253]
#  [ 195 1101]]
#               precision    recall  f1-score   support
#
#       normal     0.6963    0.6386    0.6662       700
#       botnet     0.8131    0.8495    0.8309      1296
#
#    micro avg     0.7756    0.7756    0.7756      1996
#    macro avg     0.7547    0.7441    0.7486      1996
# weighted avg     0.7722    0.7756    0.7732      1996
#
# TN:  447
# FP:  253
# FN:  195
# TP:  1101
# False Alarm Rate:  0.36142857142857143
# Precision Rate:  0.8131462333825702
# Recall Rate:  0.8495370370370371
#
# [[ 374  326]
#  [  97 1199]]
#               precision    recall  f1-score   support
#
#       normal     0.7941    0.5343    0.6388       700
#       botnet     0.7862    0.9252    0.8501      1296
#
#    micro avg     0.7881    0.7881    0.7881      1996
#    macro avg     0.7901    0.7297    0.7444      1996
# weighted avg     0.7890    0.7881    0.7760      1996
#
# TN:  374
# FP:  326
# FN:  97
# TP:  1199
# False Alarm Rate:  0.4657142857142857
# Precision Rate:  0.7862295081967213
# Recall Rate:  0.9251543209876543
#
# [[ 350  350]
#  [  74 1222]]
#               precision    recall  f1-score   support
#
#       normal     0.8255    0.5000    0.6228       700
#       botnet     0.7774    0.9429    0.8522      1296
#
#    micro avg     0.7876    0.7876    0.7876      1996
#    macro avg     0.8014    0.7215    0.7375      1996
# weighted avg     0.7942    0.7876    0.7717      1996
#
# TN:  350
# FP:  350
# FN:  74
# TP:  1222
# False Alarm Rate:  0.5
# Precision Rate:  0.77735368956743
# Recall Rate:  0.9429012345679012
#
# [[ 355  345]
#  [  82 1214]]
#               precision    recall  f1-score   support
#
#       normal     0.8124    0.5071    0.6245       700
#       botnet     0.7787    0.9367    0.8504      1296
#
#    micro avg     0.7861    0.7861    0.7861      1996
#    macro avg     0.7955    0.7219    0.7374      1996
# weighted avg     0.7905    0.7861    0.7712      1996
#
# TN:  355
# FP:  345
# FN:  82
# TP:  1214
# False Alarm Rate:  0.4928571428571429
# Precision Rate:  0.7787042976266838
# Recall Rate:  0.9367283950617284
#
# [[ 498  202]
#  [ 242 1054]]
#               precision    recall  f1-score   support
#
#       normal     0.6730    0.7114    0.6917       700
#       botnet     0.8392    0.8133    0.8260      1296
#
#    micro avg     0.7776    0.7776    0.7776      1996
#    macro avg     0.7561    0.7624    0.7588      1996
# weighted avg     0.7809    0.7776    0.7789      1996
#
# TN:  498
# FP:  202
# FN:  242
# TP:  1054
# False Alarm Rate:  0.2885714285714286
# Precision Rate:  0.839171974522293
# Recall Rate:  0.8132716049382716
#
# [[ 352  348]
#  [  73 1223]]
#               precision    recall  f1-score   support
#
#       normal     0.8282    0.5029    0.6258       700
#       botnet     0.7785    0.9437    0.8532      1296
#
#    micro avg     0.7891    0.7891    0.7891      1996
#    macro avg     0.8034    0.7233    0.7395      1996
# weighted avg     0.7959    0.7891    0.7734      1996
#
# TN:  352
# FP:  348
# FN:  73
# TP:  1223
# False Alarm Rate:  0.49714285714285716
# Precision Rate:  0.7784850413749205
# Recall Rate:  0.9436728395061729
#
# [[ 282  418]
#  [  73 1223]]
#               precision    recall  f1-score   support
#
#       normal     0.7944    0.4029    0.5346       700
#       botnet     0.7453    0.9437    0.8328      1296
#
#    micro avg     0.7540    0.7540    0.7540      1996
#    macro avg     0.7698    0.6733    0.6837      1996
# weighted avg     0.7625    0.7540    0.7282      1996
#
# TN:  282
# FP:  418
# FN:  73
# TP:  1223
# False Alarm Rate:  0.5971428571428572
# Precision Rate:  0.7452772699573431
# Recall Rate:  0.9436728395061729
#
# [[ 390  310]
#  [  85 1211]]
#               precision    recall  f1-score   support
#
#       normal     0.8211    0.5571    0.6638       700
#       botnet     0.7962    0.9344    0.8598      1296
#
#    micro avg     0.8021    0.8021    0.8021      1996
#    macro avg     0.8086    0.7458    0.7618      1996
# weighted avg     0.8049    0.8021    0.7911      1996
#
# TN:  390
# FP:  310
# FN:  85
# TP:  1211
# False Alarm Rate:  0.44285714285714284
# Precision Rate:  0.7961867192636424
# Recall Rate:  0.9344135802469136
# ```

# %% [markdown]
# RANDOM POSITION 10 EXPERIMENTS MAXLEN=75 lSTM
# ```
# [[ 631   69]
#  [  96 1200]]
#               precision    recall  f1-score   support
#
#       normal     0.8680    0.9014    0.8844       700
#       botnet     0.9456    0.9259    0.9357      1296
#
#    micro avg     0.9173    0.9173    0.9173      1996
#    macro avg     0.9068    0.9137    0.9100      1996
# weighted avg     0.9184    0.9173    0.9177      1996
#
# TN:  631
# FP:  69
# FN:  96
# TP:  1200
# False Alarm Rate:  0.09857142857142857
# Precision Rate:  0.9456264775413712
# Recall Rate:  0.9259259259259259
#
# [[ 624   76]
#  [  61 1235]]
#               precision    recall  f1-score   support
#
#       normal     0.9109    0.8914    0.9011       700
#       botnet     0.9420    0.9529    0.9474      1296
#
#    micro avg     0.9314    0.9314    0.9314      1996
#    macro avg     0.9265    0.9222    0.9243      1996
# weighted avg     0.9311    0.9314    0.9312      1996
#
# TN:  624
# FP:  76
# FN:  61
# TP:  1235
# False Alarm Rate:  0.10857142857142857
# Precision Rate:  0.9420289855072463
# Recall Rate:  0.9529320987654321
#
# [[ 618   82]
#  [  82 1214]]
#               precision    recall  f1-score   support
#
#       normal     0.8829    0.8829    0.8829       700
#       botnet     0.9367    0.9367    0.9367      1296
#
#    micro avg     0.9178    0.9178    0.9178      1996
#    macro avg     0.9098    0.9098    0.9098      1996
# weighted avg     0.9178    0.9178    0.9178      1996
#
# TN:  618
# FP:  82
# FN:  82
# TP:  1214
# False Alarm Rate:  0.11714285714285715
# Precision Rate:  0.9367283950617284
# Recall Rate:  0.9367283950617284
#
# [[ 576  124]
#  [  50 1246]]
#               precision    recall  f1-score   support
#
#       normal     0.9201    0.8229    0.8688       700
#       botnet     0.9095    0.9614    0.9347      1296
#
#    micro avg     0.9128    0.9128    0.9128      1996
#    macro avg     0.9148    0.8921    0.9018      1996
# weighted avg     0.9132    0.9128    0.9116      1996
#
# TN:  576
# FP:  124
# FN:  50
# TP:  1246
# False Alarm Rate:  0.17714285714285713
# Precision Rate:  0.9094890510948905
# Recall Rate:  0.9614197530864198
#
# [[ 626   74]
#  [  84 1212]]
#               precision    recall  f1-score   support
#
#       normal     0.8817    0.8943    0.8879       700
#       botnet     0.9425    0.9352    0.9388      1296
#
#    micro avg     0.9208    0.9208    0.9208      1996
#    macro avg     0.9121    0.9147    0.9134      1996
# weighted avg     0.9211    0.9208    0.9210      1996
#
# TN:  626
# FP:  74
# FN:  84
# TP:  1212
# False Alarm Rate:  0.10571428571428572
# Precision Rate:  0.942457231726283
# Recall Rate:  0.9351851851851852
#
# [[ 614   86]
#  [  77 1219]]
#               precision    recall  f1-score   support
#
#       normal     0.8886    0.8771    0.8828       700
#       botnet     0.9341    0.9406    0.9373      1296
#
#    micro avg     0.9183    0.9183    0.9183      1996
#    macro avg     0.9113    0.9089    0.9101      1996
# weighted avg     0.9181    0.9183    0.9182      1996
#
# TN:  614
# FP:  86
# FN:  77
# TP:  1219
# False Alarm Rate:  0.12285714285714286
# Precision Rate:  0.9340996168582375
# Recall Rate:  0.9405864197530864
#
# [[ 618   82]
#  [  91 1205]]
#               precision    recall  f1-score   support
#
#       normal     0.8717    0.8829    0.8772       700
#       botnet     0.9363    0.9298    0.9330      1296
#
#    micro avg     0.9133    0.9133    0.9133      1996
#    macro avg     0.9040    0.9063    0.9051      1996
# weighted avg     0.9136    0.9133    0.9135      1996
#
# TN:  618
# FP:  82
# FN:  91
# TP:  1205
# False Alarm Rate:  0.11714285714285715
# Precision Rate:  0.9362859362859363
# Recall Rate:  0.9297839506172839
#
# [[ 645   55]
#  [ 108 1188]]
#               precision    recall  f1-score   support
#
#       normal     0.8566    0.9214    0.8878       700
#       botnet     0.9558    0.9167    0.9358      1296
#
#    micro avg     0.9183    0.9183    0.9183      1996
#    macro avg     0.9062    0.9190    0.9118      1996
# weighted avg     0.9210    0.9183    0.9190      1996
#
# TN:  645
# FP:  55
# FN:  108
# TP:  1188
# False Alarm Rate:  0.07857142857142857
# Precision Rate:  0.9557522123893806
# Recall Rate:  0.9166666666666666
#
# [[ 637   63]
#  [ 117 1179]]
#               precision    recall  f1-score   support
#
#       normal     0.8448    0.9100    0.8762       700
#       botnet     0.9493    0.9097    0.9291      1296
#
#    micro avg     0.9098    0.9098    0.9098      1996
#    macro avg     0.8971    0.9099    0.9026      1996
# weighted avg     0.9126    0.9098    0.9105      1996
#
# TN:  637
# FP:  63
# FN:  117
# TP:  1179
# False Alarm Rate:  0.09
# Precision Rate:  0.9492753623188406
# Recall Rate:  0.9097222222222222
#
# [[ 582  118]
#  [  61 1235]]
#               precision    recall  f1-score   support
#
#       normal     0.9051    0.8314    0.8667       700
#       botnet     0.9128    0.9529    0.9324      1296
#
#    micro avg     0.9103    0.9103    0.9103      1996
#    macro avg     0.9090    0.8922    0.8996      1996
# weighted avg     0.9101    0.9103    0.9094      1996
#
# TN:  582
# FP:  118
# FN:  61
# TP:  1235
# False Alarm Rate:  0.16857142857142857
# Precision Rate:  0.9127864005912787
# Recall Rate:  0.9529320987654321
# ```

# %%
f1_maxlen75_lstm = [0.9324, 0.9291, 0.9358, 0.9330, 0.9373, 0.9388, 0.9347, 0.9367, 0.9464, 0.9357]
recall_maxlen75_lstm = [0.9529, 0.9097, 0.9167, 0.9298, 0.9406, 0.9352, 0.9614, 0.9367, 0.9529, 0.9259]
precision_maxlen75_lstm = [0.9128, 0.9493, 0.9558, 0.9363, 0.9341, 0.9425, 0.9095, 0.9367, 0.9420, 0.9456]
fp_maxlen75_lstm = 1-np.array([0.1685, 0.09, 0.078, 0.1171, 0.1228, 0.1057, 0.1771, 0.1171, 0.1085, 0.0985])
f1_maxlen25_lstm = [0.8598, 0.8328, 0.8532, 0.8260, 0.8504, 0.8522, 0.8501, 0.8309, 0.8393, 0.8272]
recall_maxlen25_lstm = [0.9344, 0.9437, 0.9437, 0.8133, 0.9367, 0.9429, 0.9252, 0.8495, 0.8542, 0.7739]
precision_maxlen25_lstm = [0.7962, 0.7453, 0.7785, 0.8392, 0.7787, 0.7774, 0.7862, 0.8131, 0.8249, 0.8884]
fp_maxlen25_lstm = 1-np.array([0.4428, 0.5971, 0.4971, 0.2885, 0.4928, 0.5, 0.4657, 0.3614, 0.3357, 0.18])
f1_maxlen25_rf = [0.91,0.91,0.91,0.91,0.90,0.91,0.91,0.91,0.91,0.91]
recall_maxlen25_rf = [0.94,0.94,0.94,0.94,0.94,0.93,0.93,0.95,0.93,0.95]
precision_maxlen25_rf = [0.88,0.88,0.88,0.88,0.87,0.88,0.89,0.88,0.88,0.87]
fp_maxlen25_rf = [0.69,0.72,0.69,0.7,0.68,0.71,0.73,0.72,0.71,0.68]
f1_maxlen75_rf = [0.91,0.92,0.91,0.92,0.91,0.91,0.91,0.91,0.91,0.91]
recall_maxlen75_rf = [0.95,0.95,0.94,0.95,0.95,0.94,0.95,0.95,0.94,0.95]
precision_maxlen75_rf = [0.88,0.89,0.88,0.89,0.88,0.88,0.88,0.87,0.88,0.87]
fp_maxlen75_rf = [0.71,0.73,0.72,0.73,0.71,0.72,0.71,0.70,0.71,0.69]
model = []
model[0:10] = ["LSTM-75" for i in range(10)]
model[10:20] = ["LSTM-25" for i in range(10)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.DataFrame({"F1-Score":f1_maxlen75_lstm + f1_maxlen25_lstm,
                  "Precision":precision_maxlen75_lstm + precision_maxlen25_lstm,
                  "Recall":recall_maxlen75_lstm + recall_maxlen25_lstm,
                  "Specificity":np.concatenate((fp_maxlen75_lstm,fp_maxlen25_lstm)),
                  "model":model})
fig, axes = plt.subplots(2, 2, figsize=(15,10))

ax = sns.boxplot(y="model", x="F1-Score", data=df, 
    ax=axes[0, 0])
ax = sns.boxplot(y="model", x="Precision", data=df, 
    ax=axes[0, 1])
ax = sns.boxplot(y="model", x="Recall", data=df, 
    ax=axes[1, 0])
ax = sns.boxplot(y="model", x="Specificity", data=df, 
    ax=axes[1, 1])
#sns.boxplot(x="F1-Score", y="model", data=df)

# %%
df1 = pd.DataFrame({"F1-Score":f1_maxlen75_lstm,
                  "Precision":precision_maxlen75_lstm,
                  "Recall":recall_maxlen75_lstm,
                  "Specificity":fp_maxlen75_lstm})#,
                  #"model":model})
df2 = pd.DataFrame({"F1-Score":f1_maxlen25_lstm,
                  "Precision":precision_maxlen25_lstm,
                  "Recall":recall_maxlen25_lstm,
                  "Specificity":fp_maxlen25_lstm})
df3 = pd.DataFrame({"F1-Score":f1_maxlen25_rf,
                  "Precision":precision_maxlen25_rf,
                  "Recall":recall_maxlen25_rf,
                  "Specificity":fp_maxlen25_rf})
df4 = pd.DataFrame({"F1-Score":f1_maxlen75_rf,
                  "Precision":precision_maxlen75_rf,
                  "Recall":recall_maxlen75_rf,
                  "Specificity":fp_maxlen75_rf})

fig, axes = plt.subplots(1, 4, figsize=(20,6))
sns.boxplot(data=df1.iloc[:,0:4], ax=axes[0])
sns.boxplot(data=df2.iloc[:,0:4], ax=axes[1])
sns.boxplot(data=df3.iloc[:,0:4], ax=axes[2])
sns.boxplot(data=df4.iloc[:,0:4], ax=axes[3])
axes[0].set_title('LSTM-75',fontweight="bold")
axes[1].set_title('LSTM-25',fontweight="bold")
axes[2].set_title('RF-25',fontweight="bold")
axes[3].set_title('RF-75',fontweight="bold")
plt.savefig("random_pos_summary.jpg")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv("../Datasets/test.csv")

# %%
df["Specificity"] = df.iloc[0::2]["Recall"]

# %%
df["Specificity"] = df["Specificity"].shift(1)

# %%
df1 = df.iloc[::2]

# %%
df = pd.read_csv("../Datasets/test_rf.csv")

# %%
df2 = df.iloc[1::2]
df2.head()
# Out:
#          F1  Precision    Recall  Support  Specificity
# 1  0.909231   0.872110  0.949652   1867.0     0.695193
# 3  0.899229   0.861152  0.940828   1859.0     0.672474
# 5  0.908058   0.884751  0.932626   1885.0     0.725749
# 7  0.901576   0.866005  0.940194   1856.0     0.687500
# 9  0.904738   0.879208  0.931794   1906.0     0.700246

# %%
df2.drop("Support", axis=1, inplace=True)
# Out:
# /home/franco/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,6))
sns.boxplot(data=df1.iloc[:,0:4], ax=axes[0])
sns.boxplot(data=df2.iloc[:,0:4], ax=axes[1])
axes[0].set_title('LSTM-Endgame-Maxlen10',fontweight="bold")
axes[1].set_title('RF-Maxlen10',fontweight="bold")
plt.savefig("random_pos_summary_10.jpg")
